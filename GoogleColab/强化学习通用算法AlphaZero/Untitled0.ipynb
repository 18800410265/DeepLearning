# %% [markdown]
# <a href="https://colab.research.google.com/github/18800410265/DeepLearning/blob/main/GoogleColab/%E5%BC%BA%E5%8C%96%E5%AD%A6%E4%B9%A0%E9%80%9A%E7%94%A8%E7%AE%97%E6%B3%95AlphaZero/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
class ActorCritic:
  def __init__(self,state_dim,action_dim):
    self.state_dim=state_dim
    self.action_dim=action_dim

# %%
from tensorflow.keras.datasets import boston_housing

# %%
(train_data,train_labels),(test_data,test_labels) = boston_housing.load_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
print(train_data[0:5])
# Out:
# [[1.23247e+00 0.00000e+00 8.14000e+00 0.00000e+00 5.38000e-01 6.14200e+00
#   9.17000e+01 3.97690e+00 4.00000e+00 3.07000e+02 2.10000e+01 3.96900e+02
#   1.87200e+01]
#  [2.17700e-02 8.25000e+01 2.03000e+00 0.00000e+00 4.15000e-01 7.61000e+00
#   1.57000e+01 6.27000e+00 2.00000e+00 3.48000e+02 1.47000e+01 3.95380e+02
#   3.11000e+00]
#  [4.89822e+00 0.00000e+00 1.81000e+01 0.00000e+00 6.31000e-01 4.97000e+00
#   1.00000e+02 1.33250e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.75520e+02
#   3.26000e+00]
#  [3.96100e-02 0.00000e+00 5.19000e+00 0.00000e+00 5.15000e-01 6.03700e+00
#   3.45000e+01 5.98530e+00 5.00000e+00 2.24000e+02 2.02000e+01 3.96900e+02
#   8.01000e+00]
#  [3.69311e+00 0.00000e+00 1.81000e+01 0.00000e+00 7.13000e-01 6.37600e+00
#   8.84000e+01 2.56710e+00 2.40000e+01 6.66000e+02 2.02000e+01 3.91430e+02
#   1.46500e+01]]

# %%
import pandas as pd
import numpy as np
column=['crin','zn','indus',
        'chas','nox','rm',
        'age','dis','rad',
        'tax','ptratio','b','lstat']
df= pd.DataFrame(train_data,columns=column)
df.head()
# Out:
#       crin    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
#
#    ptratio       b  lstat
# 0     21.0  396.90  18.72
# 1     14.7  395.38   3.11
# 2     20.2  375.52   3.26
# 3     20.2  396.90   8.01
# 4     20.2  391.43  14.65

# %%
mean=train_data.mean()
std=train_data.std()
train_data=(train_data-mean)/std
df=pd.DataFrame(train_data,columns=column)
df.head()
# Out:
#        crin        zn     indus      chas       nox        rm       age  \
# 0 -0.474821 -0.483356 -0.426982 -0.483356 -0.479630 -0.440819  0.151721
# 1 -0.483206  0.088005 -0.469297 -0.483356 -0.480482 -0.430653 -0.374625
# 2 -0.449433 -0.483356 -0.358003 -0.483356 -0.478986 -0.448936  0.209203
# 3 -0.483082 -0.483356 -0.447413 -0.483356 -0.479790 -0.441547 -0.244423
# 4 -0.457779 -0.483356 -0.358003 -0.483356 -0.478418 -0.439199  0.128866
#
#         dis       rad       tax   ptratio         b     lstat
# 0 -0.455814 -0.455654  1.642801 -0.337919  2.265412 -0.353709
# 1 -0.439933 -0.469505  1.926750 -0.381550  2.254885 -0.461818
# 2 -0.474128 -0.317142  4.129089 -0.343459  2.117343 -0.460779
# 3 -0.441905 -0.448728  1.067977 -0.343459  2.265412 -0.427882
# 4 -0.465578 -0.317142  4.129089 -0.343459  2.227529 -0.381896

# %%
import torch
import torch.optim as optim
nn =torch.nn
model=nn.Sequential(
    nn.Linear(13, 64),
    nn.ReLU(),
    nn.Linear(64,64),
    nn.ReLU(),
    nn.Linear(64,1)
)
modelOptim=optim.Adam(model.parameters(),lr=0.001)
loss=nn.MSELoss()
